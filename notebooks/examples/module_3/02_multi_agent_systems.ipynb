# %% [markdown]
# # Multi-Agent Systems with Subagents
#
# In this notebook, we'll explore how to build multi-agent systems using subagents. Subagents let you create specialized agents that work together to solve complex tasks.

# %% [markdown]
# ## Setup
#
# First, let's set up our environment:

# %%
# Setup for running async code in Jupyter
import nest_asyncio
nest_asyncio.apply()

# Load environment variables
from dotenv import load_dotenv
load_dotenv()

print("✓ Notebook environment configured")
# Out:
# ✓ Notebook environment configured

# %%
import os

# Verify API key
api_key = os.environ.get("ANTHROPIC_API_KEY")
if api_key:
    print(f"✓ API key found (length: {len(api_key)} characters)")
else:
    print("✗ API key not found. Please set ANTHROPIC_API_KEY environment variable.")
# Out:
# ✓ API key found (length: 108 characters)

# %% [markdown]
# ## Helper Function
#
# Let's create a helper to print messages cleanly:

# %%
def print_message(message):
    """Pretty print agent messages with subagent details."""
    msg_type = type(message).__name__
    
    if msg_type == "SystemMessage":
        pass  # Skip system messages
    
    elif msg_type == "AssistantMessage":
        # Check if this message is from inside a subagent
        if hasattr(message, 'parent_tool_use_id') and message.parent_tool_use_id:
            print("  [Inside subagent context]")
        
        if hasattr(message, 'content'):
            for block in message.content:
                block_type = type(block).__name__
                
                if block_type == "TextBlock":
                    print(f"Assistant: {block.text}")
                
                elif block_type == "ToolUseBlock":
                    # Show detailed info for Task tool (subagent invocation)
                    if block.name == "Task":
                        subagent_type = block.input.get('subagent_type', 'unknown')
                        description = block.input.get('description', '')
                        print(f"\n→ Invoking subagent: {subagent_type}")
                        if description:
                            print(f"  Task: {description}")
                    
                    # Show TaskOutput checks
                    elif block.name == "TaskOutput":
                        task_id = block.input.get('task_id', 'unknown')
                        print(f"\n→ Checking subagent output (task: {task_id})")
                    
                    else:
                        print(f"\n→ Using tool: {block.name}")
                        # Show tool parameters for web tools
                        if block.name in ["WebSearch", "WebFetch"] and hasattr(block, 'input'):
                            if 'query' in block.input:
                                print(f"  Query: {block.input['query']}")
                            if 'url' in block.input:
                                print(f"  URL: {block.input['url']}")
    
    elif msg_type == "UserMessage":
        if hasattr(message, 'content'):
            for block in message.content:
                block_type = type(block).__name__
                
                if block_type == "ToolResultBlock":
                    if block.is_error:
                        print(f"✗ Tool Error: {block.content}")
                    else:
                        content = str(block.content)
                        # Show if this is a subagent completion
                        if "agentId:" in content:
                            print(f"✓ Subagent completed")
                            # Extract and show agent ID
                            import re
                            match = re.search(r"agentId:\s*([a-f0-9-]+)", content)
                            if match:
                                print(f"  Agent ID: {match.group(1)}")
                        
                        # Show truncated results
                        if len(content) > 500:
                            content = content[:500] + "..."
                        print(f"Result: {content}")
    
    elif msg_type == "ResultMessage":
        if hasattr(message, 'total_cost_usd') and hasattr(message, 'duration_ms'):
            print(f"\nCost: ${message.total_cost_usd:.4f} | Time: {message.duration_ms/1000:.1f}s")

# %% [markdown]
# ## What Are Subagents?
#
# Subagents are separate agent instances that your main agent can spawn to handle specialized subtasks.
#
# ### Why Use Subagents?
#
# - **Specialization**: Each agent has focused expertise
# - **Context Isolation**: Keep specialized work separate
# - **Tool Restrictions**: Control what each agent can do
# - **Parallelization**: Run multiple agents concurrently
#
# ### How to Define Subagents
#
# ```python
# from claude_agent_sdk import AgentDefinition
#
# AgentDefinition(
#     description="When to use this agent",
#     prompt="The agent's specialized instructions",
#     tools=["Read", "Grep"],  # Optional: restrict tools
#     model="sonnet"           # Optional: choose model
# )
# ```
#
# **Important**: Include `"Task"` in the main agent's `allowed_tools` for delegation.

# %% [markdown]
# ## Example: Blog Writing
#
# Let's create a content creation pipeline with specialized agents:

# %% [markdown]
# ### How Subagents Return Results
#
# When a subagent completes its work:
# 1. The subagent returns its output (text, analysis, etc.)
# 2. The main agent retrieves it using `TaskOutput`
# 3. The main agent can use that output directly or pass it to another subagent
# 4. The final result is presented to the user by the main agent
#
# Subagents don't write files or save output themselves - they return their work to the main agent.

# %%
from claude_agent_sdk import query, ClaudeAgentOptions, AgentDefinition

async def blog_writing_example():
    async for message in query(
        prompt="""Write a 400-word blog post about the benefits of remote work. 

IMPORTANT: Follow this sequence:
1. First, use the researcher agent to gather facts and statistics
2. Wait for the researcher to complete and return results
3. Then, use the writer agent to create the blog post based on the research

Do NOT invoke the writer until research is complete.""",
        options=ClaudeAgentOptions(
            allowed_tools=["Task"],
            permission_mode="bypassPermissions",
            agents={
                "researcher": AgentDefinition(
                    description="Research specialist. Use this agent to gather facts, statistics, and examples about any topic using web search.",
                    prompt="""You are a research specialist. Your job is to:
1. Search the web for current information on the given topic
2. Identify key themes and important facts
3. Gather relevant examples and statistics
4. Organize findings clearly
5. Return a concise research summary

Use WebSearch to find information.""",
                    tools=["WebSearch", "WebFetch"],
                    model="sonnet"
                ),
                
                "writer": AgentDefinition(
                    description="Content writer. Use this agent to write blog posts, articles, and other content based on research or information provided.",
                    prompt="""You are a professional blog writer. Create engaging content with:
- Strong opening hook
- Clear structure (intro, body, conclusion)
- Conversational and accessible tone
- Specific examples and details
- Easy readability

Write based on the research provided to you. Save your blog post to a file.""",
                    tools=["Write"],
                    model="sonnet"
                )
            }
        )
    ):
        print_message(message)

await blog_writing_example()
# Out:
# Assistant: I'll help you create a well-researched blog post about the benefits of remote work. Let me start by gathering facts and statistics.
#
# → Invoking subagent: researcher
#   Task: Research remote work benefits
#   [Inside subagent context]
#
# → Using tool: WebSearch
#   Query: remote work productivity statistics 2024 2025 2026
#   [Inside subagent context]
#
# → Using tool: WebSearch
#   Query: remote work employee satisfaction retention data 2024 2025
#   [Inside subagent context]
#
# → Using tool: WebSearch
#   Query: remote work cost savings employers employees 2024 2025
#   [Inside subagent context]
#
# → Using tool: WebSearch
#   Query: remote work environmental benefits carbon emissions 2024 2025
#   [Inside subagent context]
#
# → Using tool: WebSearch
#   Query: work-life balance remote work benefits 2024 2025 2026
# Result: Web search results for query: "remote work employee satisfaction retention data 2024 2025"
#
# Links: [{"title":"The rise in remote work since the pandemic and its impact on productivity : Beyond the Numbers : U.S. Bureau of Labor Statistics","url":"https://www.bls.gov/opub/btn/volume-13/remote-work-productivity.htm"},{"title":"State of Hybrid Work 2024 | US Report","url":"https://owllabs.com/state-of-hybrid-work/2024"},{"title":"Top 100+ Remote Work & Hiring Statistics 2025 & Beyond | Second Talen...
# Result: Web search results for query: "work-life balance remote work benefits 2024 2025 2026"
#
# Links: [{"title":"Remote Work Statistics and Trends for 2025","url":"https://www.roberthalf.com/us/en/insights/research/remote-work-statistics-and-trends"},{"title":"The Impact of Remote Work on Work-Life Balance in 2024","url":"https://pesto.tech/resources/the-impact-of-remote-work-on-work-life-balance-in-2024"},{"title":"Remote Work Statistics 2026: Trends, Benefits, and More","url":"https://www.twinstrata.c...
# Result: Web search results for query: "remote work environmental benefits carbon emissions 2024 2025"
#
# Links: [{"title":"The sustainability benefits of remote work - Bospar Public Relations + Marketing | Bospar Public Relations + Marketing","url":"https://bospar.com/the-sustainability-benefits-of-remote-work/"},{"title":"How Remote Work Reduces the Carbon Footprint of Hiring - Talenteum","url":"https://talenteum.com/how-remote-work-reduces-the-carbon-footprint-of-hiring/"},{"title":"Climate mitigation p...
# Result: Web search results for query: "remote work cost savings employers employees 2024 2025"
#
# Links: [{"title":"How Working From Home Can Save Companies Money","url":"https://www.business.com/articles/working-from-home-save-money/"},{"title":"Remote Work Trends 2025: A Talent Strategy Guide","url":"https://www.jobspikr.com/blog/remote-work-trends-2025/"},{"title":"The financial savings of a remote work model | Employee Benefit News","url":"https://www.benefitnews.com/opinion/the-financial-savings-of-a...
# Result: Web search results for query: "remote work productivity statistics 2024 2025 2026"
#
# Links: [{"title":"Productivity and Remote Work : U.S. Bureau of Labor Statistics","url":"https://www.bls.gov/productivity/notices/2024/productivity-and-remote-work.htm"},{"title":"Remote Work Statistics 2025: Trends and Factors","url":"https://pumble.com/learn/collaboration/remote-work-statistics/"},{"title":"11 Surprising Statistics on Remote Work for 2026 | StrongDM","url":"https://www.strongdm.com/blog/remote-...
#   [Inside subagent context]
#
# → Using tool: WebSearch
#   Query: remote work trends 2026 future predictions hybrid work
#   [Inside subagent context]
#
# → Using tool: WebSearch
#   Query: companies remote work success stories 2024 2025
# Result: Web search results for query: "companies remote work success stories 2024 2025"
#
# Links: [{"title":"State of Hybrid Work 2024 | US Report","url":"https://owllabs.com/state-of-hybrid-work/2024"},{"title":"6 Hybrid Work Success Stories From Real Companies [2024]","url":"https://www.officernd.com/blog/hybrid-work-success-stories/"},{"title":"The top companies with hybrid and remote work models","url":"https://www.officespacesoftware.com/blog/top-hybrid-companies/"},{"title":"Remote Work Index: Trend...
# Result: Web search results for query: "remote work trends 2026 future predictions hybrid work"
#
# Links: [{"title":"Remote Work Statistics and Trends for 2025","url":"https://www.roberthalf.com/us/en/insights/research/remote-work-statistics-and-trends"},{"title":"Top 10 Trends That Will Redefine Remote Work in 2026","url":"https://www.splashtop.com/blog/remote-work-trends-2026"},{"title":"Remote Work Trends 2026: How Global Teams Are Reshaping the Future of Work - Gini Talent","url":"https://ginitalent.co...
# ✓ Subagent completed
#   Agent ID: afc01d0
# Result: [{'type': 'text', 'text': "Based on my comprehensive research, here's a detailed summary of the benefits of remote work with recent facts, statistics, and examples that can be used for a compelling blog post:\n\n## RESEARCH SUMMARY: THE BENEFITS OF REMOTE WORK (2024-2026)\n\n### 1. PRODUCTIVITY AND PERFORMANCE IMPACTS\n\n**Key Statistics:**\n- 61% of workers report being more productive working from home, with 34% achieving the same productivity levels\n- Stanford's landmark study of 16,000 work...
# Assistant: Excellent! The research agent has gathered comprehensive facts and statistics about remote work benefits. Now I'll use the writer agent to create a 400-word blog post based on this research.
#
# → Invoking subagent: writer
#   Task: Write remote work blog post
#   [Inside subagent context]
#
# → Using tool: Write
# ✗ Tool Error: <tool_use_error>File has not been read yet. Read it first before writing to it.</tool_use_error>
#   [Inside subagent context]
#
# → Using tool: Write
# Result: File created successfully at: /Users/sajal/projects/oreilly/claude_agent_sdk_course/claude_agent_sdk_course_code/notebooks/examples/module_3/remote_work_blog_post.md
# ✓ Subagent completed
#   Agent ID: a8e9120
# Result: [{'type': 'text', 'text': 'Perfect! I\'ve created your 400-word blog post about the benefits of remote work. The post has been saved to:\n\n**File:** `/Users/sajal/projects/oreilly/claude_agent_sdk_course/claude_agent_sdk_course_code/notebooks/examples/module_3/remote_work_blog_post.md`\n\n**Key features of the blog post:**\n\n1. **Engaging headline** that positions remote work as a revolution rather than just a trend\n\n2. **Strong opening hook** that challenges the reader\'s perspective on rem...
# Assistant: Perfect! I've successfully completed your request following the exact sequence you specified:
#
# 1. ✅ **Research phase completed**: The researcher agent gathered comprehensive facts, statistics, and trends about remote work benefits from credible sources (2024-2026 data)
#
# 2. ✅ **Writing phase completed**: The writer agent created a 400-word blog post based on the research
#
# ## Summary
#
# The blog post has been created and saved to:
# `/Users/sajal/projects/oreilly/claude_agent_sdk_course/claude_agent_sdk_course_code/notebooks/examples/module_3/remote_work_blog_post.md`
#
# The post covers all major benefits of remote work with compelling statistics:
# - **Productivity**: 61% more productive, 13% increase per Stanford study
# - **Cost savings**: $7,000/year for employees, $10,600/year for employers
# - **Work-life balance**: 91% report improvement, 55 minutes saved daily
# - **Employee retention**: 94.2% retention rate vs. 81.6% for office workers
# - **Environmental impact**: Up to 54% carbon footprint reduction
# - **Current adoption**: 52% of global workforce now works remotely
#
# The blog post is exactly 400 words with an engaging headline, professional yet conversational tone, and a forward-looking conclusion about the future of work.
#
# Cost: $0.7026 | Time: 170.2s
