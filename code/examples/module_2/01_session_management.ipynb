# %% [markdown]
# # Session Management
#
# In this notebook, we'll explore how to manage sessions, maintain context across interactions, and use session forking to explore different approaches.

# %% [markdown]
# ## Setup
#
# First, let's set up our environment:

# %%
# Setup for running async code in Jupyter
import nest_asyncio
nest_asyncio.apply()

# Load optional environment variables from a .env file (if present).
# This course uses your Claude subscription, so no ANTHROPIC_API_KEY is needed --
# load_dotenv() is here only for optional keys (e.g. TAVILY_API_KEY), or an
# ANTHROPIC_API_KEY if you choose per-token API billing instead.
from dotenv import load_dotenv
load_dotenv()

print("✓ Notebook environment configured")
# Out:
# ✓ Notebook environment configured

# %% [markdown]
# ## Authentication
#
# This course runs on your **Claude Pro/Max subscription** — no API key or per-token billing required.
#
# **One-time setup:**
#
# 1. Install the Claude Code CLI. The Python SDK drives it under the hood (it is *not* bundled with `claude-agent-sdk`):
#    ```bash
#    # macOS / Linux (native installer)
#    curl -fsSL https://claude.ai/install.sh | bash
#    # or with npm:  npm install -g @anthropic-ai/claude-code
#    ```
# 2. Log in with your Claude account:
#    ```bash
#    claude        # opens a browser to log in (use /login if not prompted)
#    ```
#    Inside `claude`, run `/status` to confirm you're authenticated via your subscription.
#
# > ⚠️ **Precedence gotcha:** if `ANTHROPIC_API_KEY` is set in your environment, the SDK uses it (per-token API billing) and **ignores your subscription**. For subscription use, keep `ANTHROPIC_API_KEY` unset — don't put it in `.env`.
#
# See the [Claude Code quickstart](https://code.claude.com/docs/en/quickstart) for Windows and other install options.
#
# ### Optional: use an API key instead
#
# Prefer per-token API billing? You don't need to change any code — just make the key available in the environment and the SDK picks it up automatically:
#
# ```bash
# # Option A - shell environment variable
# export ANTHROPIC_API_KEY="sk-ant-..."
# ```
#
# ```bash
# # Option B - add to a .env file in the project (the setup cell above calls load_dotenv())
# # ANTHROPIC_API_KEY=sk-ant-...
# ```
#
# ```python
# # (Optional) confirm which auth the SDK will use:
# # import os
# # print("API key billing" if os.environ.get("ANTHROPIC_API_KEY") else "Claude subscription")
# ```

# %% [markdown]
# ## Helper Function
#
# Let's create a helper to print messages cleanly:

# %%
import json

def print_message(message):
    """Pretty print agent messages."""
    msg_type = type(message).__name__
    
    if msg_type == "SystemMessage":
        # Print session info from init messages
        if hasattr(message, 'subtype') and message.subtype == 'init':
            session_id = message.data.get('session_id')
            print(f"🔄 Session initialized: {session_id}")
            return session_id
    
    elif msg_type == "AssistantMessage":
        if hasattr(message, 'content'):
            for block in message.content:
                block_type = type(block).__name__
                if block_type == "TextBlock":
                    print(f"🤖 Assistant: {block.text}")
                elif block_type == "ToolUseBlock":
                    print(f"🔧 Tool: {block.name}")
                    if hasattr(block, 'input') and 'description' in block.input:
                        print(f"   → {block.input['description']}")
    
    elif msg_type == "UserMessage":
        if hasattr(message, 'content'):
            for block in message.content:
                block_type = type(block).__name__
                if block_type == "ToolResultBlock":
                    if block.is_error:
                        print(f"❌ Tool Error: {block.content}")
                    else:
                        content = str(block.content)
                        if len(content) > 300:
                            content = content[:300] + "..."
                        print(f"📤 Tool Result: {content}")
    
    elif msg_type == "ResultMessage":
        if hasattr(message, 'total_cost_usd') and hasattr(message, 'duration_ms'):
            print(f"\n💰 Cost: ${message.total_cost_usd:.4f} | ⏱️ Time: {message.duration_ms/1000:.1f}s")
    
    return None

# %% [markdown]
# ## How Sessions Work
#
# When you start a new query, the SDK automatically creates a session and returns a session ID in the initial system message. This session ID can be used to:
#
# - **Resume** the conversation to continue building linearly
# - **Fork** the conversation to create independent branches for exploring alternatives
#
# ### Key Concepts
#
# - **Session ID**: Unique identifier for a conversation thread
# - **Resume**: Continue the same session linearly (keeps same session ID)
# - **Fork**: Create a new session that branches from the current state (generates new session ID)
# - **Context**: All previous messages and tool results are maintained in each session
#
# ### The Workflow We'll Demonstrate
#
# 1. **Create** initial content (formal announcement)
# 2. **Fork** to try a different approach (casual version) - preserves original
# 3. **Resume original** session to add more content (FAQ in formal tone)
# 4. **Resume forked** session to add the same content (FAQ in casual tone)
#
# This shows how fork enables you to maintain multiple independent versions that evolve separately.

# %% [markdown]
# ## Example 1: Starting a New Session
#
# Let's start by asking the agent to help us write a formal announcement:

# %%
from claude_agent_sdk import query, ClaudeAgentOptions

print("=" * 60)
print("Starting a new session")
print("=" * 60)

async def capture_session_id():
    session_id = None
    
    async for message in query(
        prompt="Write a brief announcement about our office returning to 3 days in-office policy starting next month",
        options=ClaudeAgentOptions(model="sonnet")
    ):
        # Capture session ID from init message
        if hasattr(message, 'subtype') and message.subtype == 'init':
            session_id = message.data.get('session_id')
            print(f"📝 Session started with ID: {session_id}\n")
        
        # Print other messages
        print_message(message)
    
    return session_id

# Capture the session ID for later use
saved_session_id = await capture_session_id()
print(f"\n✅ Saved session ID: {saved_session_id}")
# Out:
# ============================================================
# Starting a new session
# ============================================================
# 📝 Session started with ID: 73dd9ab3-2bce-4e1b-8e2b-0cb9a067de4c
#
# 🔄 Session initialized: 73dd9ab3-2bce-4e1b-8e2b-0cb9a067de4c
# 🤖 Assistant: Here's a brief announcement:
#
# ---
#
# **Subject: Updated In-Office Policy — Starting July 2026**
#
# Hi Team,
#
# Starting next month, we'll be transitioning to a **3-days-in-office** policy.
#
# Beginning **July 1, 2026**, all employees are expected to be in the office a minimum of three days per week. You'll have flexibility in choosing which days work best for you and your team, though we encourage coordination with your manager and teammates to ensure good overlap.
#
# We believe this balance supports both the collaboration and energy that come from being together in person, while preserving the flexibility many of us have come to value.
#
# Please reach out to your manager or HR with any questions. We're looking forward to seeing more of you soon.
#
# Thanks,
# [Your Name / Leadership Team]
#
# ---
#
# Let me know if you'd like to adjust the tone, add specific days, include any exceptions, or tailor it to your company's voice.
#
# 💰 Cost: $0.1247 | ⏱️ Time: 9.6s
#
# ✅ Saved session ID: 73dd9ab3-2bce-4e1b-8e2b-0cb9a067de4c

# %% [markdown]
# ### What Happened?
#
# 1. The query started and created a new session
# 2. The first message was a `SystemMessage` with `subtype='init'`
# 3. We extracted the `session_id` from `message.data`
# 4. The agent wrote a formal email announcement
# 5. We saved the session ID - this will be our "main branch"
#
# **Next**: We'll fork this session to create a casual version while keeping the formal one intact.

# %% [markdown]
# ## Example 2: Forking to Try a Different Approach
#
# Instead of continuing linearly, let's **fork** to create a casual version while preserving the formal one:

# %%
print("\n" + "=" * 60)
print("Forking to create a casual version")
print("=" * 60)

async def fork_session():
    forked_session_id = None
    
    async for message in query(
        prompt="Rewrite this announcement as a casual Slack message instead",
        options=ClaudeAgentOptions(
            resume=saved_session_id,
            fork_session=True,  # Fork to create a new branch
            model="sonnet"
        )
    ):
        # Capture the new forked session ID
        if hasattr(message, 'subtype') and message.subtype == 'init':
            forked_session_id = message.data.get('session_id')
            print(f"🔀 Forked session created: {forked_session_id}")
            print(f"   Original session: {saved_session_id}")
            print(f"   Same? {forked_session_id == saved_session_id}\n")
        
        print_message(message)
    
    return forked_session_id

casual_session_id = await fork_session()
print(f"\n✅ Casual (forked) session ID: {casual_session_id}")
# Out:
# ============================================================
# Forking to create a casual version
# ============================================================
# 🔀 Forked session created: 4539c4cb-2111-4988-a1db-e9867aca6bb6
#    Original session: 73dd9ab3-2bce-4e1b-8e2b-0cb9a067de4c
#    Same? False
#
# 🔄 Session initialized: 4539c4cb-2111-4988-a1db-e9867aca6bb6
# 🤖 Assistant: Here's a casual Slack version:
#
# ---
#
# 👋 **Quick update on our office policy!**
#
# Starting **July 1st**, we're moving to **3 days in-office** per week. You've got flexibility on which days you come in, just coordinate with your team so there's good overlap.
#
# We think it'll be a nice mix — more face time together without losing the flexibility you're used to. 🙌
#
# Any questions? Drop them below or ping your manager. See you in the office! 🏢
#
# ---
#
# Want me to tweak the tone, add a specific contact, or remove the emojis?
#
# 💰 Cost: $0.0105 | ⏱️ Time: 7.5s
#
# ✅ Casual (forked) session ID: 4539c4cb-2111-4988-a1db-e9867aca6bb6

# %% [markdown]
# ### What Just Happened?
#
# - Created a **new session ID** (fork)
# - The fork started with the formal announcement context
# - Rewrote it in a casual tone
# - **Original session is preserved** - we can still continue the formal version
#
# Now we have TWO independent sessions:
# - **Session A** (original): Formal announcement
# - **Session B** (fork): Casual Slack version

# %% [markdown]
# ## Example 3: Resume Original Session (Formal Version)
#
# Let's continue building the **formal version** by adding an FAQ section:

# %%
print("\n" + "=" * 60)
print("Resuming ORIGINAL session (formal version)")
print("=" * 60)

async def resume_formal():
    async for message in query(
        prompt="Add a FAQ section with questions about parking, which days are required, and flexibility for special circumstances",
        options=ClaudeAgentOptions(
            resume=saved_session_id,  # Resume the original formal session
            model="sonnet"
        )
    ):
        print_message(message)

await resume_formal()
# Out:
# ============================================================
# Resuming ORIGINAL session (formal version)
# ============================================================
# 🔄 Session initialized: 73dd9ab3-2bce-4e1b-8e2b-0cb9a067de4c
# 🤖 Assistant: Here's the updated announcement with the FAQ section added:
#
# ---
#
# **Subject: Updated In-Office Policy — Starting July 2026**
#
# Hi Team,
#
# Starting next month, we'll be transitioning to a **3-days-in-office** policy.
#
# Beginning **July 1, 2026**, all employees are expected to be in the office a minimum of three days per week. You'll have flexibility in choosing which days work best for you and your team, though we encourage coordination with your manager and teammates to ensure good overlap.
#
# We believe this balance supports both the collaboration and energy that come from being together in person, while preserving the flexibility many of us have come to value.
#
# Please reach out to your manager or HR with any questions. We're looking forward to seeing more of you soon.
#
# Thanks,
# [Your Name / Leadership Team]
#
# ---
#
# **Frequently Asked Questions**
#
# **Which days am I required to come in?**
# There are no mandatory specific days — you have the flexibility to choose which three days work best for you each week. That said, we encourage you to align with your team to maximize in-person collaboration. Your manager may set team-wide anchor days, so check in with them for any team-specific guidance.
#
# **What about parking?**
# Parking is available at [location/garage name] on a first-come, first-served basis. Employees can also apply for a reserved parking permit through HR. We recommend arriving before [time] to secure a spot on busier days. Subsidized transit options remain available as an alternative — details can be found on the intranet.
#
# **Can I request flexibility for special circumstances?**
# Yes. We understand that life doesn't always follow a schedule. If you have a medical need, caregiving responsibility, or another extenuating circumstance, please speak with your manager or contact HR to discuss accommodations. Requests will be handled on a case-by-case basis and treated with discretion.
#
# ---
#
# Want me to adjust any of the answers, add more FAQ entries, or fill in the placeholder details?
#
# 💰 Cost: $0.0137 | ⏱️ Time: 11.3s

# %% [markdown]
# ### Notice:
#
# - Used the **original session ID** (saved_session_id)
# - Agent maintained the **formal tone** from the original announcement
# - FAQ is professional and structured
# - This session has NO knowledge of the casual Slack version

# %% [markdown]
# ## Example 4: Resume Forked Session (Casual Version)
#
# Now let's continue the **casual Slack version** by adding the same FAQ content but in a casual tone:

# %%
print("\n" + "=" * 60)
print("Resuming FORKED session (casual version)")
print("=" * 60)

async def resume_casual():
    async for message in query(
        prompt="Add a FAQ section with questions about parking, which days are required, and flexibility for special circumstances",
        options=ClaudeAgentOptions(
            resume=casual_session_id,  # Resume the forked casual session
            model="sonnet"
        )
    ):
        print_message(message)

await resume_casual()
# Out:
# ============================================================
# Resuming FORKED session (casual version)
# ============================================================
# 🔄 Session initialized: 4539c4cb-2111-4988-a1db-e9867aca6bb6
# 🤖 Assistant: Here's the updated Slack message with a FAQ section:
#
# ---
#
# 👋 **Quick update on our office policy!**
#
# Starting **July 1st**, we're moving to **3 days in-office** per week. You've got flexibility on which days you come in, just coordinate with your team so there's good overlap.
#
# We think it'll be a nice mix — more face time together without losing the flexibility you're used to. 🙌
#
# Any questions? Drop them below or ping your manager. See you in the office! 🏢
#
# ---
#
# **FAQ**
#
# **🅿️ What about parking?**
# Parking is available on a first-come, first-served basis. If you're planning to drive in regularly, we recommend reaching out to [Facilities/HR] to ask about reserved spot options or any commuter benefits available to you.
#
# **📅 Are there specific days I'm required to come in?**
# Nope — no mandatory days (for now). You and your team get to decide which 3 days work best. That said, check in with your manager to align on expectations for your team's overlap days.
#
# **🙋 What if I have a special circumstance?**
# Life happens! If you have a medical need, caregiving responsibility, or another situation that makes 3 days difficult, reach out to your manager or HR to work something out. We'll handle these on a case-by-case basis.
#
# ---
#
# Want me to add more FAQs, adjust any of the answers, or fill in placeholder details like the HR contact?
#
# 💰 Cost: $0.0133 | ⏱️ Time: 9.7s

# %% [markdown]
# ### Notice:
#
# - Used the **forked session ID** (casual_session_id)
# - Agent maintained the **casual, friendly tone** from the Slack message
# - Same FAQ content but adapted to the casual context
# - This session has NO knowledge of the formal version's FAQ
